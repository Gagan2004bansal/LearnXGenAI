# %%
import os 
os.environ['OPENAI_API_KEY'] = ""

# %%
# !pip install -q langchain-openai langchain-community langchain-core requests duckduckgo-search

# %%
# !pip install -U ddgs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 861.5/861.5 kB 5.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [ddgs]
# ...

# %%
from langchain_openai import OpenAI
from langchain_core.tools import tool
import requests
from langchain_community.tools import DuckDuckGoSearchRun
search_tool = DuckDuckGoSearchRun()

response = search_tool.run("Top News in Haryana today")

# %%
response
# Out:
# '1 day ago - Haryana News (हरियाणा समाचार) in Hindi: Get the latest Haryana news (हरियाणा की खबरें) in hindi at Aaj Tak Online. Also get the hindi news from India, world, politics, business, election, crime, education, movies, sports and so on at Aaj ... 3 weeks ago - Youngsters came out in the open as they got respite from the heat, but crops were affected from the hailstorm · HC seeks Haryana govt’s reply, allows Dr Satpal to rejoin as SMO at CHC Chiri in Rohtak; the court posted the matter for October 27 16 hours ago - Haryana Weather: नौतपा में बदला हरियाणा का मौसम, तापमान में गिरावट; 4 जून तक वर्षा की चेतावनी 1 month ago - Gurugram News: करीब 5 करोड़ रुपये की लागत से हरियाणा पुलिस को मिले 312 इमरजेंसी रिस्पांस व्हीकल; 21 जून तक प्रदेशभर में चलेंगे ... 18 hours ago - Haryana News in Hindi (हरियाणा समाचार): पढ़ें 3 जून सुबह 10 बजे के ताज़ा समाचार, देश की न.1 न्यूज़ एप्प दैनिक भास्कर पर. Read 3 June 10AM Latest Haryana News @Dainik ...'

# %%
llm = ChatOpenAI()

# %%
from langchain.agents import create_react_agent, AgentExecutor
from langchain import hub

# %%
prompt = hub.pull("hwchase17/react")

# %%
agent = create_react_agent(
    llm=llm,
    tools=[search_tool],
    prompt=prompt
)

# %%
agent_executor = AgentExecutor(
    agent=agent, 
    tools=[search_tool],
    verbose=True
)

# %%
response = agent_executor.run({"input": "How i can reach dehradun from Tohana"})
print(response)
